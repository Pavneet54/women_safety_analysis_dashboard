# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv("CrimesOnWomenData_Updated_Till_2024.csv")

# Show the top 5 rows to verify
df.head()
# Out:
#    Numbers              State  Year No. of Rape cases Kidnap And Assault  \
# 0        0     ANDHRA PRADESH  2001               871                765
# 1        1  ARUNACHAL PRADESH  2001                33                 55
# 2        2              ASSAM  2001               817               1070
# 3        3              BIHAR  2001               888                518
# 4        4       CHHATTISGARH  2001               959                171
#
#    Dowry Deaths Assault against women  Assault against modesty of women  \
# 0           420                  3544                              2271
# 1             0                    78                                 3
# 2            59                   850                                 4
# 3           859                   562                                21
# 4            70                  1763                               161
#
#    Domestic violence  Women Trafficking Notes
# 0               5791                  7   NaN
# 1                 11                  0   NaN
# 2               1248                  0   NaN
# 3               1558                 83   NaN
# 4                840                  0   NaN

# %%
# Clean column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_").str.replace(".", "", regex=False)

# Drop unnecessary columns
df.drop(columns=['numbers', 'notes'], inplace=True)

# Confirm changes
df.head()
# Out:
#                state  year no_of_rape_cases kidnap_and_assault  dowry_deaths  \
# 0     ANDHRA PRADESH  2001              871                765           420
# 1  ARUNACHAL PRADESH  2001               33                 55             0
# 2              ASSAM  2001              817               1070            59
# 3              BIHAR  2001              888                518           859
# 4       CHHATTISGARH  2001              959                171            70
#
#   assault_against_women  assault_against_modesty_of_women  domestic_violence  \
# 0                  3544                              2271               5791
# 1                    78                                 3                 11
# 2                   850                                 4               1248
# 3                   562                                21               1558
# 4                  1763                               161                840
#
#    women_trafficking
# 0                  7
# 1                  0
# 2                  0
# 3                 83
# 4                  0

# %%
# Check null values
df.isnull().sum()

# Fill nulls with 0
df.fillna(0, inplace=True)

# %%
# Ensure 'year' is integer
df['year'] = df['year'].astype(int)

# Convert crime counts to numeric
crime_cols = df.columns.drop(['state', 'year'])
df[crime_cols] = df[crime_cols].apply(pd.to_numeric, errors='coerce')

# %%
def assign_period(year):
    if year <= 2010:
        return '2001–2010: Pre-Nirbhaya'
    elif year <= 2015:
        return '2011–2015: Post-Nirbhaya'
    elif year <= 2019:
        return '2016–2019: Digital & Policing'
    elif year <= 2022:
        return '2020–2022: COVID Era'
    else:
        return '2023–2024: Provisional'

df['period'] = df['year'].apply(assign_period)

# Preview
df.head()
# Out:
#                state  year  no_of_rape_cases  kidnap_and_assault  \
# 0     ANDHRA PRADESH  2001             871.0               765.0
# 1  ARUNACHAL PRADESH  2001              33.0                55.0
# 2              ASSAM  2001             817.0              1070.0
# 3              BIHAR  2001             888.0               518.0
# 4       CHHATTISGARH  2001             959.0               171.0
#
#    dowry_deaths  assault_against_women  assault_against_modesty_of_women  \
# 0           420                 3544.0                              2271
# 1             0                   78.0                                 3
# 2            59                  850.0                                 4
# 3           859                  562.0                                21
# 4            70                 1763.0                               161
#
#    domestic_violence  women_trafficking                   period
# 0               5791                  7  2001–2010: Pre-Nirbhaya
# 1                 11                  0  2001–2010: Pre-Nirbhaya
# 2               1248                  0  2001–2010: Pre-Nirbhaya
# 3               1558                 83  2001–2010: Pre-Nirbhaya
# 4                840                  0  2001–2010: Pre-Nirbhaya

# %%
df.columns.tolist()
# Out:
# ['state',
#  'year',
#  'no_of_rape_cases',
#  'kidnap_and_assault',
#  'dowry_deaths',
#  'assault_against_women',
#  'assault_against_modesty_of_women',
#  'domestic_violence',
#  'women_trafficking',
#  'period']

# %%
crime_columns = [
    'no_of_rape_cases',
    'kidnap_and_assault',
    'dowry_deaths',
    'assault_against_women',
    'assault_against_modesty_of_women',
    'domestic_violence',
    'women_trafficking'
]

df['total_crimes'] = df[crime_columns].sum(axis=1)

# %%
df[['state', 'year', 'total_crimes']].head()
# Out:
#                state  year  total_crimes
# 0     ANDHRA PRADESH  2001       13669.0
# 1  ARUNACHAL PRADESH  2001         180.0
# 2              ASSAM  2001        4048.0
# 3              BIHAR  2001        4489.0
# 4       CHHATTISGARH  2001        3964.0

# %%
df['is_provisional'] = df['year'].apply(lambda x: 1 if x >= 2023 else 0)

# %%
df.to_csv("Cleaned_Crime_Data_2001_2024.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("CrimesOnWomenData_Updated_Till_2024.csv")
df.head()  # Check first few rows
# Out:
#    Numbers              State  Year No. of Rape cases Kidnap And Assault  \
# 0        0     ANDHRA PRADESH  2001               871                765
# 1        1  ARUNACHAL PRADESH  2001                33                 55
# 2        2              ASSAM  2001               817               1070
# 3        3              BIHAR  2001               888                518
# 4        4       CHHATTISGARH  2001               959                171
#
#    Dowry Deaths Assault against women  Assault against modesty of women  \
# 0           420                  3544                              2271
# 1             0                    78                                 3
# 2            59                   850                                 4
# 3           859                   562                                21
# 4            70                  1763                               161
#
#    Domestic violence  Women Trafficking Notes
# 0               5791                  7   NaN
# 1                 11                  0   NaN
# 2               1248                  0   NaN
# 3               1558                 83   NaN
# 4                840                  0   NaN

# %%
df.isnull().sum()
# Out:
# Numbers                               0
# State                                 0
# Year                                  0
# No. of Rape cases                     0
# Kidnap And Assault                    0
# Dowry Deaths                          0
# Assault against women                 0
# Assault against modesty of women      0
# Domestic violence                     0
# Women Trafficking                     0
# Notes                               759
# dtype: int64

# %%
df['Notes'] = df['Notes'].fillna('NA')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 763 entries, 0 to 762
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Numbers                           763 non-null    int64
#  1   State                             763 non-null    object
#  2   Year                              763 non-null    int64
#  3   No. of Rape cases                 763 non-null    object
#  4   Kidnap And Assault                763 non-null    object
#  5   Dowry Deaths                      763 non-null    int64
#  6   Assault against women             763 non-null    object
#  7   Assault against modesty of women  763 non-null    int64
#  8   Domestic violence                 763 non-null    int64
#  9   Women Trafficking                 763 non-null    int64
#  10  Notes                             763 non-null    object
# dtypes: int64(6), object(5)
# memory usage: 65.7+ KB

# %%
import re

# Use regex to extract only digits
for col in cols_to_convert:
    df[col] = df[col].astype(str).str.extract(r'(\d+)')  # Extract numeric part
    df[col] = df[col].astype(float).fillna(0).astype(int)  # Convert to int safely

# %%
df[cols_to_convert].dtypes
# Out:
# No. of Rape cases        int32
# Kidnap And Assault       int32
# Assault against women    int32
# dtype: object

# %%
df['State'].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND',
#        'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI',
#        'DAMAN & DIU', 'LAKSHADWEEP', 'PUDUCHERRY', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'A & N Islands', 'Chandigarh', 'D&N Haveli',
#        'Daman & Diu', 'Delhi UT', 'Lakshadweep', 'Puducherry', 'Delhi'],
#       dtype=object)

# %%
# Strip spaces and convert to Title Case (e.g., "Andhra Pradesh")
df['State'] = df['State'].str.strip().str.title()

# %%
df['State'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'A & N Islands', 'Chandigarh', 'D & N Haveli',
#        'Daman & Diu', 'Lakshadweep', 'Puducherry', 'Telangana',
#        'D&N Haveli', 'Delhi Ut', 'Delhi'], dtype=object)

# %%
# Create a mapping dictionary
state_name_mapping = {
    'A & N Islands': 'Andaman & Nicobar Islands',
    'D & N Haveli': 'Dadra & Nagar Haveli and Daman & Diu',
    'D&N Haveli': 'Dadra & Nagar Haveli and Daman & Diu',
    'Daman & Diu': 'Dadra & Nagar Haveli and Daman & Diu',
    'Delhi Ut': 'Delhi',
    'Delhi': 'Delhi',  # Keep as 'Delhi'
}

# Replace using the mapping
df['State'] = df['State'].replace(state_name_mapping)

# %%
df['State'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal', 'Andaman & Nicobar Islands', 'Chandigarh',
#        'Dadra & Nagar Haveli and Daman & Diu', 'Lakshadweep',
#        'Puducherry', 'Telangana', 'Delhi'], dtype=object)

# %%
df['Year'].min(), df['Year'].max()
# Out:
# (2001, 2024)

# %%
df.describe()
# Out:
#           Numbers         Year  No. of Rape cases  Kidnap And Assault  \
# count  763.000000   763.000000         763.000000          763.000000
# mean   381.000000  2011.542595        1163.338139         1096.336828
# std    220.403418     6.291202        3912.564602         1968.748951
# min      0.000000  2001.000000           0.000000            0.000000
# 25%    190.500000  2006.000000          36.000000           14.000000
# 50%    381.000000  2012.000000         361.000000          249.000000
# 75%    571.500000  2017.000000        1097.000000         1158.500000
# max    762.000000  2024.000000       59691.000000        15381.000000
#
#        Dowry Deaths  Assault against women  Assault against modesty of women  \
# count    763.000000             763.000000                        763.000000
# mean     208.060288            1523.237221                        320.948886
# std      419.231993            2437.461520                        794.002121
# min        0.000000               0.000000                          0.000000
# 25%        0.000000              25.500000                          2.000000
# 50%       22.000000             342.000000                         28.000000
# 75%      254.000000            1944.500000                        255.500000
# max     2524.000000           14853.000000                       9422.000000
#
#        Domestic violence  Women Trafficking
# count         763.000000         763.000000
# mean         2503.247706          27.727392
# std          3998.635159          78.749072
# min             0.000000           0.000000
# 25%             9.000000           0.000000
# 50%           588.000000           0.000000
# 75%          3426.000000          12.000000
# max         23278.000000         549.000000

# %%
df.to_csv("Cleaned_CrimesOnWomen_2001_2024.csv", index=False)
